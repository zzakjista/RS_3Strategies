# %%
import pandas as pd
import numpy as np
import bson
import json

# %%
import torch.nn as nn
import torch
from attention import MultiHeadedAttention
from utils import SublayerConnection, PositionwiseFeedForward

attention = MultiHeadedAttention(h=4, d_model=256, dropout=0.3)
input_sublayer = SublayerConnection(size=256, dropout=0.3)

# %%
x = torch.randn(64,256)
query, key, value = attention.forward(x, x, x, mask=None)

# %%
query.shape
# Out:
# torch.Size([64, 4, 1, 64])

# %%
def forward(x, mask):
    x = input_sublayer(x, lambda _x: attention.forward(_x, _x, _x, mask=mask))
    return x
x = torch.randn(32,256)
forward(x,None).shape
# Out:
# torch.Size([32, 32, 256])

# %%
PATH = 'C:/github/RS_DATASETS/pinterest_iccv/pinterest_iccv/'

# %%
with open(PATH+'subset_iccv_board_cate.bson', 'rb') as f:
    cate = []
    for rows in bson.decode_file_iter(f):
        cate.append(rows)
cate = pd.DataFrame(cate)
with open(PATH+'subset_iccv_board_pins.bson', 'rb') as f:
    data = []
    for rows in bson.decode_file_iter(f):
        data.append(rows)
data = pd.DataFrame(data)
with open(PATH+'subset_iccv_pin_im.bson', 'rb') as f:
    im = []
    for rows in bson.decode_file_iter(f):
        im.append(rows)
im = pd.DataFrame(im)

# %%
PATH = 'C:/github/RS_DATASETS/beauty/'
with open(PATH + 'All_Beauty.json','rb') as f:
    beauty = []
    for rows in f.readlines():
        beauty.append(json.loads(rows))

# %%
with open(PATH + 'meta_All_Beauty.json','rb') as f:
    meta = []
    for rows in f.readlines():
        meta.append(json.loads(rows))

# %%
beauty = pd.DataFrame(beauty)
meta = pd.DataFrame(meta)

# %%
PATH = 'C:/github/RS_DATASETS/luxury_beauty/'
with open(PATH + 'luxury_beauty.json','rb') as f:
    luxury_beauty = []
    for rows in f.readlines():
        luxury_beauty.append(json.loads(rows))
with open(PATH + 'meta_luxury_beauty.json','rb') as f:
    meta_luxury_beauty = []
    for rows in f.readlines():
        meta_luxury_beauty.append(json.loads(rows))

# %%
luxury_beauty = pd.DataFrame(luxury_beauty)
meta_luxury_beauty = pd.DataFrame(meta_luxury_beauty)

# %%
meta_luxury_beauty['category']
# Out:
# 0        []
# 1        []
# 2        []
# 3        []
# 4        []
#          ..
# 12294    []
# 12295    []
# 12296    []
# 12297    []
# 12298    []
# Name: category, Length: 12299, dtype: object

# %%
meta['main_cat'].unique()
# Out:
# array(['All Beauty'], dtype=object)

# %%
with open('C:/github/RS_DATASETS/meta_Appliances.json/' + 'meta_Appliances.json','rb') as f:
    meta_Appliances = []
    for rows in f.readlines():
        meta_Appliances.append(json.loads(rows))
meta_Appliances = pd.DataFrame(meta_Appliances)

# %%
meta_Appliances.loc[10,'category']
# Out:
# ['Appliances',
#  'Parts &amp; Accessories',
#  'Dryer Parts &amp; Accessories',
#  'Replacement Parts']

# %%
meta
# Out:
#       category tech1                                        description fit  \
# 0           []        [Loud 'N Clear Personal Sound Amplifier allows...
# 1           []        [No7 Lift & Luminate Triple Action Serum 50ml ...
# 2           []        [No7 Stay Perfect Foundation now stays perfect...
# 3           []                                                       []
# 4           []        [Lacto Calamine Skin Balance Daily Nourishing ...
# ...        ...   ...                                                ...  ..
# 32887       []                                                       []
# 32888       []                                                       []
# 32889       []                                                       []
# 32890       []        [Brand new and high quality<br> Enables fast v...
# 32891       []                                                       []
#
#                                                    title  \
# ...

# %%
meta_Appliances
# Out:
#                                                 category  \
# 0      [Appliances, Refrigerators, Freezers & Ice Mak...
# 1      [Appliances, Refrigerators, Freezers & Ice Mak...
# 2                  [Appliances, Parts &amp; Accessories]
# 3                      [Appliances, Parts & Accessories]
# 4      [Appliances, Parts & Accessories, Range Parts ...
# ...                                                  ...
# 30440                  [Appliances, Parts & Accessories]
# 30441                  [Appliances, Parts & Accessories]
# 30442                  [Appliances, Parts & Accessories]
# 30443  [Appliances, Parts & Accessories, Range Parts ...
# 30444                  [Appliances, Parts & Accessories]
#
#                                                    tech1  \
# 0       class="a-keyvalue prodDetTable" role="present...
# 1       class="a-keyvalue prodDetTable" role="present...
# 2
# 3       class="a-keyvalue prodDetTable" role="present...
# ...
